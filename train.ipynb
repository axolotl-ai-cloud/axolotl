# %%
# !pip3 install --ignore-installed "axolotl[flash-attn,deepspeed] @ git+https://github.com/OpenAccess-AI-Collective/axolotl"

# %%
# !git clone https://github.com/code-x-0018/axolotl

# %%
cd src

# %%
pwd

# %%
import torch
from huggingface_hub import HfFolder, snapshot_download
import wandb

# %%
hf_token = ""
hf_folder = HfFolder()
hf_folder.save_token(hf_token)

wandb.login(key="")

available_gpus = torch.cuda.device_count()
print("available_gpus - ", available_gpus)

# %%
CUDA_VISIBLE_DEVICES=""

# %% [markdown]
# ## preprocess datasets

# %%
# !python -m axolotl.cli.preprocess ../examples/mistral/config.yml

# %% [markdown]
# ## finetune model

# %%
# !accelerate launch -m axolotl.cli.train ../examples/code-llama/7b/config.yml

# %% [markdown]
# ## infrence gradio

# %%
# !python -m axolotl.cli.inference ../examples/code-llama/7b/config.yml --gradio

# %% [markdown]
# ## Kill port

# %%
# !ss -ltnp | grep ':29500'

# %%
# !kill -9 18069
